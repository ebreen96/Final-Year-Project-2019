# %% [markdown]
# # Prep_400
# This notebook deals with the preparation of my fourth research question 'What python packages are being imported together regularly?'

# %% [markdown]
# ## Purpose
# * In this notebook I will be creating lists of packages imported within each notebook to be used for apriori analysis
#
#     * I will begin be reading in a dataframe of notebook info (including packages imported)
#     * The package column will be cleaned and a dataframe with lists of imports will be created
#     * This dataframe will then be transformed to a string list
#     * This string list will then be saved to a txt file

# %%
#importing relevant libraries
import os
import json
import numpy as np
import pandas as pd
import seaborn as sns
import re
import time
import datetime

# %% [markdown]
# ### Reading in dataframe

# %%
df_nb = pd.read_csv('../data/CSV_files/new_cell_info.csv')

# %%
df_nb.head()
# Out:
#     nb_id nb_language  worksheet_index  cell_index  num_imports  \
# 0  400000       julia                0         NaN            1
# 1  400000       julia                1         NaN            0
# 2  400000       julia                2         NaN            0
# 3  400000       julia                3         NaN            0
# 4  400000       julia                4         NaN            0
#
#            imports  num_headings headings header_level
# 0  ['DataFrames,']             0       []           []
# 1               []             0       []           []
# 2               []             0       []           []
# 3               []             0       []           []
# 4               []             0       []           []

# %% [markdown]
# ### Cleaning 'imports' column

# %%
df_nb['imports'] = pd.DataFrame([str(line).strip('[').strip(']').replace("'","") for line in df_nb['imports']])

# %% [markdown]
# Removing square brackets from imports column

# %%
df_imports = df_nb.replace('', np.nan) # replacing space with NaN values

# %%
df_imports = df_imports.dropna(subset=['imports']) #droping rows with no imports

# %%
df_imports.head()
# Out:
#      nb_id nb_language  worksheet_index  cell_index  num_imports  \
# 0   400000       julia                0         NaN            1
# 22  400002      python                0         NaN            1
# 41  400004      python                1         NaN            6
# 49  400004      python                9         NaN            1
# 60  400005      python                1         NaN            9
#
#                                               imports  num_headings headings  \
# 0                                         DataFrames,             0       []
# 22                                              sympy             0       []
# 41  gcp, gcp.storage, gcp.context, random, pandas,...             0       []
# 49                                            inspect             0       []
# 60  matplotlib.pyplot, numpy, os, tarfile, urllib,...             0       []
#
#    header_level
# 0            []
# 22           []
# 41           []
# 49           []
# 60           []

# %%
df_imports = df_imports[['nb_id', 'imports']]

# %% [markdown]
# Creating dataframe with just imports and notebook ID

# %%
foo = lambda a: ", ".join(a)
dfImports = df_imports.groupby('nb_id').agg({'imports': foo})

# %% [markdown]
# Join import lists based on notebook ID. This is so analysis can be done by notebook rather than by cell. (ie. some people might import in multiple cells of a notebook)

# %%
dfImports.head()
# Out:
#                                                   imports
# nb_id
# 400000                                        DataFrames,
# 400002                                              sympy
# 400004  gcp, gcp.storage, gcp.context, random, pandas,...
# 400005  matplotlib.pyplot, numpy, os, tarfile, urllib,...
# 400006  gensim, numpy, __future__, time, sklearn.featu...

# %%
dfImports = dfImports['imports'].str.split(',', expand=True).reset_index()

# %% [markdown]
# Expanding the imports out to multiple columns.

# %%
dfImports.head()
# Out:
#     nb_id                  0             1             2         3  \
# 0  400000         DataFrames                        None      None
# 1  400002              sympy          None          None      None
# 2  400004                gcp   gcp.storage   gcp.context    random
# 3  400005  matplotlib.pyplot         numpy            os   tarfile
# 4  400006             gensim         numpy    __future__      time
#
#                                   4                       5  \
# 0                              None                    None
# 1                              None                    None
# 2                            pandas                StringIO
# 3                            urllib         IPython.display
# 4   sklearn.feature_extraction.text   sklearn.decomposition
#
#                    6                      7         8  ...    294   295   296  \
# 0               None                   None      None  ...   None  None  None
# 1               None                   None      None  ...   None  None  None
# 2            inspect                   None      None  ...   None  None  None
# 3              scipy   sklearn.linear_model   cPickle  ...   None  None  None
# 4   sklearn.datasets       sklearn.datasets    gensim  ...   None  None  None
#
#     297   298   299   300   301   302   303
# 0  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None
#
# [5 rows x 305 columns]

# %%
dfImports.fillna(value=pd.np.nan, inplace=True) # replacing None values with Nan

# %%
dfImports = dfImports.drop(['nb_id'], axis = 1)  # dropping nb_id column

# %%
dfImports = dfImports.replace('nan', np.nan) #replacing nan with NaN

# %%
dfImports = dfImports.replace(np.nan, '', regex=True) #replacing all NaN values with empty space

# %% [markdown]
# Replacing NaN values id so that NaN is not counted as a package in future analysis

# %%
dfImports.shape
# Out:
# (127001, 304)

# %% [markdown]
# 127,001 lists of packages

# %% [markdown]
# ### Converting dataframe to sting list

# %%
records = []  
for i in range(0, 127001):  
    records.append(list(set([str(dfImports.values[i,j]) for j in range(0, 304)])))

# %%
cleanedList = [x for x in records if str(x) != 'nan']

# %% [markdown]
# Again getting rid of nan values in the list

# %%
str_list = [list(filter(None, lst)) for lst in records]

# %%
result = [[s.strip() for s in inner] for inner in str_list]

# %% [markdown]
# Filtering out empty strings to make a cleaned list

# %%
result
# Out:
# [['DataFrames'],
#  ['sympy'],
#  ['pandas',
#   'gcp',
#   'gcp.storage',
#   'random',
#   'inspect',
#   'StringIO',
#   'gcp.context'],
#  ['urllib',
#   'cPickle',
#   'os',
#   'numpy',
#   'sklearn.linear_model',
#   'scipy',
#   'IPython.display',
#   'tarfile',
#   'matplotlib.pyplot'],
#  ['gensim',
#   'sklearn.feature_extraction.text',
#   'collections',
#   'sklearn.datasets',
#   '__future__',
#   'sklearn.decomposition',
#   'numpy',
#   'time',
#   'gensim'],
#  ['os',
#   'matplotlib.pyplot',
#   'lasagne',
#   'os',
#   'theano.tensor',
#   'numpy',
#   'theano',
#   'lasagne.layers',
#   'IPython.display',
#   'gym',
#   'gym.wrappers'],
#  ['math'],
#  ['pandas', 'datetime'],
#  ['ThreeVector',
#   'FutureColliderTools',
#   'sys',
#   'pickle',
#   'numpy',
#   'FourVector',
#   'ROOT',
#   'FutureColliderDataLoader'],
#  ['pyspark.sql', 'pyspark.sql.types'],
#  ['pandas',
#   'random',
#   'sklearn.neighbors',
#   'matplotlib.pyplot',
#   'sklearn.metrics',
#   'sklearn.model_selection',
#   'numpy',
#   'warnings',
#   'sklearn',
#   'sklearn.cross_validation'],
#  ['pyspark.sql', 'pyspark.sql.types'],
#  ['networkx', 'matplotlib.pyplot'],
#  ['pandas', 'sklearn.preprocessing', 'matplotlib.pyplot', 'numpy'],
#  ['pprint',
#   'skimage.color',
#   'tensorflow',
#   'skimage.io',
#   'numpy',
#   'read_cifar10'],
#  ['math',
#   'torch.nn',
#   '__future__',
#   'matplotlib.pyplot',
#   'datetime',
#   'numpy',
#   'torch.autograd',
#   'torch',
#   'math',
#   'matplotlib',
#   'torch.optim'],
#  ['pandas', 'numpy', 'difflib', 'json', 'fuzzywuzzy'],
#  ['keras.preprocessing.image',
#   'scipy.misc',
#   'scipy.optimize',
#   'keras.applications',
#   'numpy',
#   'time',
#   'keras'],
#  ['math', 'datetime', 'functools'],
#  ['json', 'pprint'],
#  ['os'],
#  ['os'],
#  ['numpy.polynomial.hermite_e',
#   'scipy.io',
#   'numpy',
#   'matplotlib.pyplot',
#   'self_similarity',
#   'numpy',
#   'main',
#   'crossing_tree',
#   'fgn',
#   'numpy.fft',
#   'hermite'],
#  ['pprint', 'csv', 'json'],
#  ['pandas', 'urllib', 'socket', 'time', 're', 'MySQLdb', 'bs4'],
#  ['urllib',
#   'cPickle',
#   'os',
#   'numpy',
#   'sklearn.linear_model',
#   'scipy',
#   'IPython.display',
#   'tarfile',
#   'matplotlib.pyplot'],
#  ['os',
#   'matplotlib.pyplot',
#   'lasagne',
#   'os',
#   'theano.tensor',
#   'numpy',
#   'theano',
#   'lasagne.layers',
#   'IPython.display',
#   'gym',
#   'gym.wrappers'],
#  ['datetime', 'matplotlib.pyplot'],
#  ['codecs',
#   'random',
#   'numpy',
#   '__future__',
#   'time',
#   'sklearn.feature_extraction.text',
#   'sklearn.pipeline',
#   're',
#   'string',
#   'psycopg2',
#   'ast',
#   'pyorient',
#   'copy',
#   'gensim',
#   'os',
#   'sys',
#   'pickle',
#   'pandas.io.sql',
#   'glob',
#   'psycopg2.extras',
#   'sklearn.decomposition'],
#  ['os',
#   'jinja2',
#   'csv',
#   'IPython.display',
#   'glob',
#   'bracket_expansion',
#   'yaml',
#   'os.path'],
#  ['pandas',
#   'sklearn.ensemble',
#   'zipline.api',
#   'collections',
#   'matplotlib.pyplot',
#   'numpy',
#   'zipline'],
#  ['tensorflow', 'numpy', 'sys'],
#  ['pymongo', 'py2neo.ogm', 'time', 'py2neo', 'requests'],
#  ['IPython.html.widgets',
#   'matplotlib.mlab',
#   'numpy',
#   'math',
#   'matplotlib.pyplot'],
#  ['pandas',
#   'codecs',
#   'urllib',
#   'numpy',
#   'matplotlib.pyplot',
#   'json',
#   'datetime',
#   'math',
#   'matplotlib'],
#  ['pandas',
#   'mpl_toolkits.axes_grid1',
#   'math',
#   'matplotlib.pyplot',
#   'numpy',
#   'scipy.stats',
#   'mcmc_skewed_gaussian'],
#  ['pandas',
#   'mpl_toolkits.axes_grid1',
#   'math',
#   'matplotlib.pyplot',
#   'numpy',
#   'scipy.stats',
#   'mcmc_skewed_gaussian'],
#  ['tabulate', 'matplotlib.pyplot', 'math'],
#  ['numpy',
#   'matplotlib.pyplot',
#   'matplotlib.mlab',
#   'matplotlib.cm',
#   'numpy',
#   'matplotlib'],
#  ['pycuda.driver',
#   'CUDATools',
#   'pycuda.tools',
#   'pycuda',
#   'numpy',
#   'time',
#   'pycuda.compiler'],
#  ['pycuda.driver',
#   'CUDATools',
#   'pycuda.tools',
#   'pycuda',
#   'numpy',
#   'time',
#   'pycuda.compiler'],
#  ['urllib.request', 'bs4'],
#  ['scitool.propertie', 'numpy', 'Toolv1', 'pylab', 'numpy', 'Tools'],
#  ['pandas',
#   'sklearn.feature_extraction.text',
#   'sklearn.ensemble',
#   'pip',
#   'nltk.corpus',
#   'numpy',
#   'matplotlib.pyplot',
#   'nltk.stem.porter',
#   'sklearn.neighbors',
#   'nltk',
#   'sklearn.metrics',
#   're',
#   'sklearn',
#   'sklearn.svm',
#   'sklearn.naive_bayes',
#   'sklearn.cross_validation'],
#  ['matplotlib', 'numpy', 'matplotlib.pyplot'],
#  ['urllib',
#   'cPickle',
#   'os',
#   'numpy',
#   'sklearn.linear_model',
#   'scipy',
#   'IPython.display',
#   'tarfile',
#   'matplotlib.pyplot'],
#  ['sympy', 'math', 'ipywidgets', 'sympy.solvers', 'IPython.display'],
#  ['pandas', 'pandasql', 'matplotlib.pyplot', 'os', 'numpy', 'time'],
#  ['src.textembeddingtools',
#   'random',
#   'datetime',
#   'src.knntools',
#   'pandas',
#   'sklearn.ensemble',
#   'src.scoring',
#   're',
#   'src.tfidftools',
#   'gensim',
#   'src.postprocess',
#   'pickle',
#   'numpy',
#   'operator',
#   'matplotlib',
#   'src.preprocess',
#   'src.tools',
#   'sklearn.preprocessing',
#   'src.recencytools',
#   'scipy',
#   'tqdm',
#   'collections'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['scipy.io', 'numpy', 'matplotlib.pyplot', 'sys', 'time', 'numpy.matlib'],
#  ['numpy',
#   'skimage.measure',
#   'matplotlib.pyplot',
#   'argparse',
#   'imageio',
#   'operator',
#   'cv2',
#   'time',
#   'tqdm',
#   'PIL',
#   'math',
#   'skimage.draw'],
#  ['pandas', 'pickle', 'numpy', 're', 'time', 'tensorflow'],
#  ['larray'],
#  ['math', 'pyspark.mllib.clustering', 'numpy'],
#  ['pandas',
#   'tempfile',
#   'shutil',
#   'os',
#   'yaml',
#   'datetime',
#   'numpy',
#   'win32api',
#   'time',
#   'tqdm',
#   'win32com.client'],
#  ['agate'],
#  ['pprint',
#   'pymongo',
#   'IPython.display',
#   'json',
#   'os',
#   'xmltodict',
#   're',
#   'requests'],
#  ['urllib',
#   'cPickle',
#   'os',
#   'numpy',
#   'sklearn.linear_model',
#   'scipy',
#   'IPython.display',
#   'tarfile',
#   'matplotlib.pyplot'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['sklearn.ensemble',
#   'sklearn.neighbors',
#   'sklearn.tree',
#   'sklearn.linear_model',
#   'pipeline'],
#  ['sklearn.ensemble',
#   'sklearn.neighbors',
#   'sklearn.tree',
#   'sklearn.linear_model',
#   'pipeline'],
#  ['pandas', 'random', '__future__', 'numpy'],
#  ['numpy', 'matplotlib.pyplot'],
#  ['random', 'numpy', 'math', 'matplotlib'],
#  ['random',
#   'matplotlib.pyplot',
#   'numpy',
#   'tensorflow',
#   'tensorflow.examples.tutorials.mnist'],
#  ['IPython.display'],
#  ['networkx', 'matplotlib.pyplot'],
#  ['os',
#   'multiprocessing',
#   'comFuncs',
#   'time',
#   'functools',
#   'string',
#   'time',
#   'requests'],
#  ['os',
#   'matplotlib.pyplot',
#   'lasagne',
#   'os',
#   'theano.tensor',
#   'numpy',
#   'theano',
#   'lasagne.layers',
#   'IPython.display',
#   'gym',
#   'gym.wrappers'],
#  ['pandas',
#   'matplotlib.pyplot',
#   'numpy',
#   'sklearn.metrics.pairwise',
#   'scipy.spatial',
#   'operator',
#   'scipy.stats'],
#  ['pandas',
#   'matplotlib.pyplot',
#   'numpy',
#   'sklearn.metrics.pairwise',
#   'scipy.spatial',
#   'operator',
#   'scipy.stats'],
#  ['pandas', 'numpy', 'matplotlib.pyplot'],
#  ['networkx', 'matplotlib.pyplot'],
#  ['__future__'],
#  ['Match'],
#  ['numpy', 'matplotlib.pyplot'],
#  ['os'],
#  ['os'],
#  ['pprint', 'html5lib', 'sys', 'IPython.display', 'urllib2', 'bs4'],
#  ['pyspark.sql', 'pyspark.sql.types'],
#  ['OpOp.Model',
#   'numpy',
#   'matplotlib.pyplot',
#   'matplotlib',
#   'astropy.constants'],
#  ['pandas',
#   'matplotlib',
#   'sklearn.preprocessing',
#   'matplotlib.pyplot',
#   'scipy.sparse',
#   'numpy'],
#  ['pandas',
#   'sklearn.ensemble',
#   'numpy',
#   'matplotlib.pyplot',
#   'sklearn.metrics',
#   'sklearn',
#   'sklearn.cross_validation',
#   'xgboost'],
#  ['time', 'dis', 'functools'],
#  ['pandas', 'matplotlib.pyplot', 'numpy', 'matplotlib'],
#  ['pandas', 'asyncio', 'graphistry', 'aiogremlin'],
#  ['numpy', 'IPython.display', 'IPython.html.widgets', 'matplotlib.pyplot'],
#  ['os', 'collections', 'operator', 'csv', 'numpy', 'sklearn'],
#  ['urllib',
#   'cPickle',
#   'os',
#   'numpy',
#   'sklearn.linear_model',
#   'scipy',
#   'IPython.display',
#   'tarfile',
#   'matplotlib.pyplot'],
#  ['pandas', 'seaborn'],
#  ['pandas', 'matplotlib.dates', 'ee', 'datetime', 'pylab', 'matplotlib'],
#  ['pandas', 'requests', 'datetime'],
#  ['networkx', 'matplotlib.pyplot'],
#  ['pandas', 'numpy', 'sys', 'os', 'scipy.misc', 'itertools'],
#  ['csv'],
#  ['__future__', 'numpy', 'tensorflow', 'six.moves'],
#  ['pandas',
#   'sklearn.feature_extraction.text',
#   'autograd.numpy',
#   'os',
#   'ipywidgets',
#   'scipy.sparse',
#   'numpy',
#   'sklearn.metrics',
#   're',
#   'IPython.display',
#   'sklearn',
#   'matplotlib',
#   'keras',
#   'os.path'],
#  ['numpy', '__future__'],
#  ['logging', 'time', 'functools', 'time'],
#  ['catplot.ep_components.ep_lines', 'catplot.ep_components.ep_canvas'],
#  ['os', 'collections', 'operator', 'csv', 'numpy', 'sklearn'],
#  ['graphlab'],
#  ['urllib',
#   'cPickle',
#   'os',
#   'numpy',
#   'sklearn.linear_model',
#   'scipy',
#   'IPython.display',
#   'tarfile',
#   'matplotlib.pyplot'],
#  ['pandas', 'tensorflow', 'os', 'sklearn.model_selection', 'tensorflow'],
#  ['numpy', 'sys', 'os'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'sklearn.base',
#   'sklearn.preprocessing',
#   'sys',
#   'numpy',
#   'sklearn.linear_model',
#   'sklearn.multiclass',
#   'sklearn.metrics',
#   'sklearn.cross_validation',
#   'xgboost'],
#  ['pandas'],
#  ['os',
#   'matplotlib.pyplot',
#   'lasagne',
#   'os',
#   'theano.tensor',
#   'numpy',
#   'theano',
#   'lasagne.layers',
#   'IPython.display',
#   'gym',
#   'gym.wrappers'],
#  ['numpy', 'matplotlib.pyplot'],
#  ['tensorflow', 'numpy'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['urllib',
#   'cPickle',
#   'os',
#   'numpy',
#   'sklearn.linear_model',
#   'scipy',
#   'IPython.display',
#   'tarfile',
#   'matplotlib.pyplot'],
#  ['pandas', 'numpy', 'matplotlib.pyplot', 'seaborn', 'pylab', 'numpy', 'math'],
#  ['scipy.io', 'numpy', 'matplotlib.pyplot', 'sys', 'time', 'numpy.matlib'],
#  ['pyspark.sql', 'pyspark.sql.types'],
#  ['urllib',
#   'cPickle',
#   'os',
#   'numpy',
#   'sklearn.linear_model',
#   'scipy',
#   'IPython.display',
#   'tarfile',
#   'matplotlib.pyplot'],
#  ['urllib',
#   'cPickle',
#   'os',
#   'numpy',
#   'sklearn.linear_model',
#   'scipy',
#   'IPython.display',
#   'tarfile',
#   'matplotlib.pyplot'],
#  ['pandas',
#   'sklearn.preprocessing',
#   'sklearn.tree',
#   'sklearn.pipeline',
#   'numpy',
#   'sklearn'],
#  ['pyspark.sql', 'pyspark.sql.types'],
#  ['pandas', 'matplotlib.pyplot', 'scipy.optimize', 'numpy', 'sklearn', 'math'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'sklearn.preprocessing',
#   'numpy',
#   'datetime',
#   'sklearn.metrics',
#   'scipy.stats',
#   'math',
#   'sklearn.cross_validation',
#   'xgboost'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['bs4', 'time', 're', 'pymongo', 'requests'],
#  ['pandas', 'numpy', 'difflib', 'json', 'fuzzywuzzy'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas', 'numpy', 'matplotlib.pyplot'],
#  ['scipy.io', 'numpy', 'matplotlib.pyplot', 'sys', 'time', 'numpy.matlib'],
#  ['pandas',
#   'pprint',
#   'sklearn.feature_extraction.text',
#   'collections',
#   'sklearn.cross_validation',
#   'sklearn.metrics',
#   'sklearn.naive_bayes',
#   'string'],
#  ['nose.tools', 'numpy', 'numpy.testing'],
#  ['nose.tools', 'numpy', 'numpy.testing'],
#  ['nose.tools', 'numpy', 'numpy.testing'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['numpy', 'tensorflow', 'tensorflow.examples.tutorials.mnist'],
#  ['frequent_direction',
#   'numpy',
#   'scipy.io',
#   'matplotlib.pyplot',
#   'time',
#   'scipy'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas', 'requests', 'bs4', 'numpy', 're'],
#  ['numpy.testing', 'numpy'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pymongo', 'py2neo.ogm', 'time', 'py2neo', 'requests'],
#  ['pandas',
#   'matplotlib.pyplot',
#   '__future__',
#   'seaborn',
#   'numpy',
#   'cStringIO',
#   'matplotlib'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['urllib',
#   'cPickle',
#   'os',
#   'numpy',
#   'sklearn.linear_model',
#   'scipy',
#   'IPython.display',
#   'tarfile',
#   'matplotlib.pyplot'],
#  ['matplotlib.image',
#   'os',
#   'moviepy.editor',
#   'numpy',
#   'cv2',
#   'IPython.display',
#   'math',
#   'matplotlib.pyplot'],
#  ['os',
#   'keras.backend.common',
#   'matplotlib.pyplot',
#   'numpy',
#   'scipy',
#   'cnn_functions',
#   'h5py',
#   'model_zoo',
#   'matplotlib',
#   'tifffile'],
#  ['os',
#   'matplotlib.pyplot',
#   'lasagne',
#   'os',
#   'theano.tensor',
#   'numpy',
#   'theano',
#   'lasagne.layers',
#   'IPython.display',
#   'gym',
#   'gym.wrappers'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['htmd.ui', 'htmd.molecule.util', 'htmd.home', 'os.path'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'numpy',
#   'seaborn',
#   'sklearn.linear_model',
#   'statsmodels.formula.api',
#   'sklearn',
#   'matplotlib'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['os',
#   'matplotlib.pyplot',
#   'lasagne',
#   'os',
#   'theano.tensor',
#   'numpy',
#   'theano',
#   'lasagne.layers',
#   'IPython.display',
#   'gym',
#   'gym.wrappers'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['networkx', 'matplotlib.pyplot'],
#  ['os',
#   'sys',
#   'vgg16',
#   '__future__',
#   'sklearn.metrics',
#   'theano',
#   'PIL',
#   'IPython.display',
#   'keras',
#   'utils'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['matplotlib', 'numpy', 'matplotlib.pyplot'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas', 'pandasql', 'matplotlib.pyplot', 'os', 'numpy', 'time'],
#  ['pandas', 'db'],
#  ['tensorflow.python.framework', 'numpy', 'matplotlib.pyplot', 'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['h5py', 'dill', 'scipy.io', 'hdf5storage', 'numpy', 'dill'],
#  ['pandas', 'numpy', 'statsmodels.api'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['urllib',
#   'cPickle',
#   'os',
#   'numpy',
#   'sklearn.linear_model',
#   'scipy',
#   'IPython.display',
#   'tarfile',
#   'matplotlib.pyplot'],
#  ['pandas',
#   'sklearn.neighbors',
#   'sklearn.tree',
#   'sklearn.model_selection',
#   'sklearn.linear_model',
#   'sklearn.discriminant_analysis',
#   'sklearn.svm',
#   'sklearn.naive_bayes',
#   'matplotlib'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['mpl_toolkits.mplot3d',
#   'neuron',
#   'single_cell_mooc_client',
#   'neuron',
#   'matplotlib.pyplot',
#   'matplotlib.collections',
#   'numpy',
#   'os;'],
#  ['landlab.io',
#   'landlab',
#   'matplotlib.pyplot',
#   'numpy',
#   'landlab.plot',
#   'IPython.display',
#   'time',
#   'matplotlib',
#   'Ecohyd_functions_DEM'],
#  ['collections', 'matplotlib.pyplot', '__future__', 're', 'functools'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas', 'numpy'],
#  ['numpy', 'matplotlib.pyplot'],
#  ['functions',
#   'os',
#   'sklearn.externals',
#   'sklearn.decomposition',
#   'pickle',
#   'numpy',
#   'time',
#   'sklearn'],
#  ['functions',
#   'os',
#   'sklearn.externals',
#   'sklearn.decomposition',
#   'pickle',
#   'numpy',
#   'time',
#   'sklearn'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tensorflow',
#   'os',
#   'sys',
#   '__future__',
#   'read_data',
#   'tensorflow.python.platform',
#   'numpy',
#   'time',
#   'math'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pyspark.sql', 'pyspark.sql.types'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pyspark.sql', 'pyspark.sql.types'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'numpy',
#   'matplotlib.pyplot',
#   'seaborn',
#   'sklearn',
#   'sklearn.cross_validation'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pyspark.sql', 'pyspark.sql.types'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'sklearn.ensemble',
#   'scipy.signal',
#   'sklearn.base',
#   'os',
#   'sklearn.svm',
#   'matplotlib.pyplot',
#   'sklearn.decomposition',
#   'numpy',
#   'sklearn.linear_model',
#   'sklearn.pipeline',
#   'scipy',
#   'sklearn.model_selection',
#   'glob',
#   'sklearn.metrics',
#   'warnings'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pkg_resources',
#   'matplotlib.pyplot',
#   'sys',
#   'libs.loaders',
#   'sklearn.model_selection',
#   'libs.metrics',
#   'libs.timer',
#   'json',
#   'xgboost',
#   'lightgbm'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['os', 'collections'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['csv'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['exp', 'sys', 'regression'],
#  ['exp', 'sys', 'regression'],
#  ['exp', 'sys', 'regression'],
#  ['exp', 'sys', 'regression'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas', 'numpy', 'nltk', 'liwc'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'pydotplus',
#   'matplotlib.pyplot',
#   'sklearn.tree',
#   'numpy',
#   'sklearn.metrics',
#   'sklearn',
#   'io',
#   'IPython.display',
#   'sklearn.cross_validation'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['numpy', 'matplotlib.pyplot', 'random'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas', 'matplotlib.pyplot', 'scipy.optimize', 'numpy', 'sklearn', 'math'],
#  ['math', 'matplotlib.pyplot', 'matplotlib.pyplot'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['keras',
#   'numpy',
#   'keras.utils',
#   'keras.layers',
#   'keras.models',
#   'IPython.display',
#   'keras.datasets',
#   'matplotlib'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['matplotlib.pyplot',
#   'prob140',
#   'datascience',
#   'numpy',
#   'itertools',
#   'scipy',
#   'math'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'finance.discountfactor',
#   'finance.products.european.swap',
#   'os',
#   'numpy',
#   'dill',
#   'sys'],
#  ['nose.tools', 'numpy', 'numpy.testing'],
#  ['pyspark.sql', 'pyspark.sql.types'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['os',
#   'matplotlib.pyplot',
#   'numpy',
#   'time',
#   'tensorflow',
#   'mlp.data_providers'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['astropy.table', 'astropy', 'numpy', 'os', 're', 'glob'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'sklearn.feature_extraction.text',
#   'sklearn.datasets',
#   'matplotlib.pyplot',
#   'numpy',
#   'sklearn.linear_model'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['os',
#   'matplotlib.pyplot',
#   'lasagne',
#   'os',
#   'theano.tensor',
#   'numpy',
#   'theano',
#   'lasagne.layers',
#   'IPython.display',
#   'gym',
#   'gym.wrappers'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'collections',
#   'tflearn',
#   'numpy',
#   'tflearn.data_utils',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['inspect', 'matplotlib', 'matplotlib.colors', 'norm_foregrounds'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'pprint',
#   'pygurujobs.job',
#   'site',
#   'dateutil.relativedelta',
#   'logging',
#   'pygurujobs.jobbase',
#   'bs4',
#   'datetime',
#   'http.client',
#   'io',
#   'pygurucore.tables',
#   'requests'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['landlab.io',
#   'landlab',
#   'matplotlib.pyplot',
#   'numpy',
#   'landlab.plot',
#   'IPython.display',
#   'time',
#   'matplotlib',
#   'Ecohyd_functions_DEM'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pyspark.sql', 'pyspark.sql.types'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'flotilla',
#   'collections',
#   'matplotlib.pyplot',
#   'seaborn',
#   '__future__',
#   'numpy',
#   'matplotlib',
#   'anchor'],
#  ['pandas',
#   'pandas.tools.plotting',
#   'subprocess',
#   'os',
#   'sklearn.preprocessing',
#   'matplotlib.pyplot',
#   'seaborn',
#   'numpy',
#   'IPython.display',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['numpy'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'timeit',
#   'nltk',
#   'numpy',
#   're',
#   'review_full',
#   'math',
#   'sqlalchemy'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas', 'plotly.graph_objs', 'plotly.offline', 'plotly.plotly'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas', 'itunes_app_review_scraper', 'sys', 'glob', 'config'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas', 'numpy', 'sklearn.linear_model'],
#  ['pandas',
#   'numpy',
#   'matplotlib.pyplot',
#   'seaborn',
#   'sklearn',
#   'sklearn.cross_validation'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas', 'pprint', 'amigocloud'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['dataset',
#   'sys',
#   'os',
#   'matplotlib.pyplot',
#   '__future__',
#   'model',
#   'pickle',
#   'numpy',
#   'IPython.display',
#   'math',
#   'matplotlib'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['csv'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['time', 'staff_solutions.sensors_demo', 'breezycreate2'],
#  ['matplotlib.pyplot', 'random'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['math', 'graphlab', 'numpy'],
#  ['pandas', 'collections', 'itertools', 'networkx', 'json'],
#  ['pandas', 'collections', 'itertools', 'networkx', 'json'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'array',
#   'array',
#   'numbers',
#   'operator',
#   'itertools',
#   'abc',
#   'numpy',
#   'functools',
#   'math',
#   'reprlib'],
#  ['numpy'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['climatools.misc', 'imp', 'os', 'sys'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'pybrain.supervised.trainers',
#   'pybrain.datasets',
#   'pickle',
#   'pybrain.structure',
#   'pybrain.tools.shortcuts'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['common.lba',
#   'mxnet.symbol',
#   'os',
#   'logging',
#   'common',
#   'argparse',
#   'mxnet',
#   'numpy',
#   'symbols',
#   'time',
#   'common.wrapper_module',
#   'common.data',
#   'common.multi_iterator',
#   'common.util'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas', 'numpy', 'sklearn.linear_model'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'sklearn.kernel_ridge',
#   'matplotlib.pyplot',
#   'datetime',
#   'operator',
#   'numpy',
#   'scipy',
#   'sklearn',
#   'sklearn.svm',
#   'json',
#   'matplotlib',
#   'requests'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'sklearn.externals',
#   'json',
#   'matplotlib.pyplot',
#   'os',
#   'seaborn',
#   '__future__',
#   'datetime',
#   'numpy',
#   'mpld3',
#   'time',
#   'warnings',
#   'glob',
#   'ast',
#   'matplotlib',
#   'sqlalchemy',
#   'requests'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'bokeh',
#   'plotly',
#   'seaborn',
#   'numpy',
#   'IPython.display',
#   'matplotlib.pyplot'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['copy', 'random'],
#  ['graphlab', 'numpy', 'matplotlib.pyplot'],
#  ['pandas', 'numpy', 'scipy'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'html5lib',
#   'numpy',
#   'matplotlib.pyplot',
#   'seaborn',
#   'sklearn.metrics',
#   'scipy',
#   'sklearn',
#   'sklearn.naive_bayes'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['pandas',
#   'timeit',
#   'nltk',
#   'numpy',
#   're',
#   'review_full',
#   'math',
#   'sqlalchemy'],
#  ['tensorflow', 'matplotlib.pyplot', 'tensorflow.examples.tutorials.mnist'],
#  ['tensorflow', 'matplotlib.pyplot', 'tensorflow.examples.tutorials.mnist'],
#  ['graphlab', 'numpy', 'matplotlib.pyplot'],
#  ['dl', 'getpass', '__future__'],
#  ['math', 'graphlab'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['IPython.core.display',
#   'sympy',
#   'numpy.linalg',
#   'numpy',
#   'scipy.linalg',
#   'warnings'],
#  ['IPython.core.display',
#   'sympy',
#   'numpy.linalg',
#   'numpy',
#   'scipy.linalg',
#   'warnings'],
#  ['embeddings',
#   'sklearn.preprocessing',
#   'pickle',
#   'graph',
#   'numpy',
#   'sklearn.metrics',
#   'sklearn.multiclass',
#   'sklearn.linear_model',
#   'sklearn.svm',
#   'sys'],
#  ['IPython.core.display',
#   'sympy',
#   'numpy.linalg',
#   'numpy',
#   'scipy.linalg',
#   'warnings'],
#  ['IPython.core.display',
#   'sympy',
#   'numpy.linalg',
#   'numpy',
#   'scipy.linalg',
#   'warnings'],
#  ['pandas',
#   'pprint',
#   'sklearn.feature_extraction.text',
#   'csv',
#   'collections',
#   'sklearn.preprocessing',
#   'sys',
#   'matplotlib.pyplot',
#   'sklearn_pandas',
#   'pylab',
#   'numpy',
#   'matplotlib'],
#  ['pandas', 'numpy', 'my_functions'],
#  ['pandas', 'sqlite3', 'numpy', 'time', 'ipaddress', 'requests'],
#  ['pandas',
#   'pybrain.supervised.trainers',
#   'pybrain.datasets',
#   'pickle',
#   'pybrain.structure',
#   'pybrain.tools.shortcuts'],
#  ['os', 'urllib3', 'datetime', 'okta'],
#  ['IPython.core.display',
#   'sympy',
#   'numpy.linalg',
#   'numpy',
#   'scipy.linalg',
#   'warnings'],
#  ['tflearn',
#   'numpy',
#   'matplotlib.pyplot',
#   'tflearn.datasets.mnist',
#   'tensorflow'],
#  ['IPython.core.display',
#   'sympy',
#   'numpy.linalg',
#   'numpy',
#   'scipy.linalg',
#   'warnings'],
#  ['os',
#   'sys',
#   'orcid',
#   'time',
#   'utilities.plossearch',
#   'pyalm.pyalm',
#   'requests'],
#  ['os',
#   'sys',
#   'orcid',
#   'time',
#   'utilities.plossearch',
#   'pyalm.pyalm',
#   'requests'],
#  ['graphlab', 'matplotlib.pyplot'],
#  ['pandas',
#   'numpy.testing',
#   'nose.tools',
#   'IPython.display',
#   'bs4',
#   'pandas.util.testing',
#   'numpy',
#   're',
#   'requests',
#   'lxml'],
#  ['pymongo', 'os', 'nose.tools', 'json', 'datetime', 'bson'],
#  ['Qconfig', 'qiskit', 'sys'],
#  ['cryptography.hazmat.primitives.ciphers',
#   'Crypto',
#   'Crypto.Hash',
#   'os',
#   'cryptography.hazmat.backends',
#   'cryptography.hazmat.primitives.asymmetric',
#   'Crypto.PublicKey',
#   'cryptography.hazmat.primitives',
#   'cryptography.hazmat.backends',
#   'Crypto.Cipher'],
#  ['Qconfig', 'qiskit', 'sys'],
#  ['scipy.misc',
#   'matplotlib.pyplot',
#   'keras.preprocessing',
#   'numpy',
#   'keras.models'],
#  ['pandas', 'numpy'],
#  ['pandas',
#   'zipfile',
#   'os',
#   'IPython.core.display',
#   'bs4',
#   'xml.etree.ElementTree',
#   'bs4'],
#  ['pymongo', 'os', 'nose.tools', 'json', 'datetime', 'bson'],
#  ['math'],
#  ['csv', 'rdflib', 'iribaker', 'SPARQLWrapper'],
#  ['pandas',
#   'sklearn.ensemble',
#   'fig_',
#   'zipfile',
#   'sklearn.feature_selection',
#   'sklearn.preprocessing',
#   'sklearn.decomposition',
#   'seaborn',
#   'ml_metrics',
#   'sklearn.pipeline',
#   'numpy',
#   'sklearn',
#   'sklearn.svm',
#   'xg',
#   'sklearn.cross_validation',
#   'matplotlib',
#   'xgboost'],
#  ['pymongo', 'os', 'nose.tools', 'json', 'datetime', 'bson'],
#  ['cky', 'IPython.display'],
#  ['matplotlib.pyplot', 'HW1'],
#  ['pandas',
#   'sklearn.ensemble',
#   'random',
#   'sklearn.neighbors',
#   'matplotlib.pyplot',
#   'seaborn',
#   'sklearn.tree',
#   'numpy',
#   'sklearn.linear_model',
#   'sklearn.model_selection',
#   'sklearn',
#   'sklearn.svm',
#   'math',
#   'sklearn.naive_bayes'],
#  ['pandas',
#   'matplotlib.pyplot',
#   'numpy',
#   'sklearn.model_selection',
#   'sklearn.metrics',
#   'sklearn',
#   'sklearn'],
#  ['pytest', 'binsearch'],
#  ['pandas',
#   'random',
#   'numpy.random',
#   'numpy',
#   'os',
#   'sklearn.neighbors',
#   'numpy',
#   'sklearn',
#   'math',
#   'sys'],
#  ['pandas', 'requests'],
#  ['pandas',
#   'mpl_toolkits.mplot3d',
#   'os',
#   'json',
#   'sys',
#   'IPython.core.display',
#   'matplotlib.pyplot',
#   'numpy',
#   're',
#   'IPython.display',
#   'IPython',
#   'matplotlib',
#   'ck.kernel'],
#  ['keras.preprocessing',
#   'os',
#   'Binary_N_DUDE',
#   'numpy',
#   'time',
#   'keras.models',
#   'theano',
#   'keras.layers.core',
#   'Binary_DUDE',
#   'keras.optimizers',
#   'keras.utils',
#   'keras'],
#  ['pymongo', 'os', 'nose.tools', 'json', 'datetime', 'bson'],
#  ['pandas',
#   'numpy.testing',
#   'nose.tools',
#   'IPython.display',
#   'bs4',
#   'pandas.util.testing',
#   'numpy',
#   're',
#   'requests',
#   'lxml'],
#  ['sympy.matrices.expressions.matmul', 'sympy', 'IPython.display'],
#  ['Qconfig', 'qiskit', 'sys'],
#  ['random',
#   'numbers',
#   'doctest',
#   'itertools',
#   'scipy',
#   'doctest',
#   'math',
#   'reprlib'],
#  ['pymongo', 'os', 'nose.tools', 'json', 'datetime', 'bson'],
#  ['numpy', 'sys', 'matplotlib.pyplot', 'multiprocessing'],
#  ['skimage.exposure',
#   'keras.layers.convolutional',
#   'keras.optimizers',
#   'tensorflow',
#   'pandas',
#   'scipy.misc',
#   'keras.preprocessing',
#   'keras.models',
#   'keras.layers',
#   'keras.layers.pooling',
#   'os',
#   'numpy',
#   'cv2',
#   'keras.layers.core',
#   'sklearn.model_selection',
#   'json',
#   'matplotlib.pyplot',
#   'csv',
#   'keras'],
#  ['pymongo', 'os', 'nose.tools', 'json', 'datetime', 'bson'],
#  ['pandas', 'matplotlib.pyplot'],
#  ['pylab', 'numpy', 'csv', 'sklearn', 'math'],
#  ['matplotlib.pyplot',
#   'cs231n.data_utils',
#   'random',
#   'numpy',
#   'time',
#   'cs231n.classifiers'],
#  ['pandas'],
#  ['numba', 'numpy', 'itertools', 'time', 'math'],
# ...
#   'os',
#   'numpy',
#   'sklearn.metrics',
#   'keras.layers.core',
#   'Utilities',
#   'Evaluation',
#   'gensim.models',
#   'nltk.corpus',
#   'keras.layers.wrappers',
#   'HomeDepotCSVReader',
#   'keras',
#   'FeatureEngineering'],
#  ['pandas',
#   'sklearn.preprocessing',
#   'matplotlib.pyplot',
#   'numpy',
#   'sklearn.linear_model',
#   'sklearn.metrics',
#   'itertools',
#   'sklearn.cross_validation'],
#  ['pandas', 'matplotlib.pyplot', 'numpy', 'scipy'],
#  ['seaborn', '__future__', 'scipy.integrate', 'math'],
#  ['pandas',
#   'sklearn.feature_selection',
#   'matplotlib.pyplot',
#   'sklearn.tree',
#   'seaborn',
#   'sklearn.grid_search',
#   'gzip',
#   'numpy',
#   'io',
#   'sklearn',
#   'sklearn.cross_validation'],
#  ['numpy', 'matplotlib.pyplot', 'os', 'sklearn', 'matplotlib', 'tensorflow'],
#  ['pandas',
#   'pandas',
#   'matplotlib.pylab',
#   'os',
#   'matplotlib.pyplot',
#   'sklearn.decomposition',
#   'sklearn.cluster',
#   'numpy',
#   'statsmodels.stats.multicomp',
#   'scipy.spatial.distance',
#   'sklearn',
#   'warnings',
#   'sklearn.cross_validation',
#   'statsmodels.formula.api'],
#  ['pandas',
#   'imblearn.under_sampling',
#   'sklearn.ensemble',
#   'numpy',
#   'matplotlib.pyplot',
#   'sklearn.decomposition',
#   'seaborn',
#   'sklearn.tree',
#   'sklearn.neighbors',
#   'sys',
#   'sklearn.model_selection',
#   'sklearn.metrics',
#   'visuals',
#   'IPython.display',
#   'sklearn.svm',
#   'sklearn',
#   'xgboost'],
#  ['pandas',
#   'pandas',
#   'pymysql',
#   'matplotlib.pyplot',
#   'statsmodels.api',
#   'datetime',
#   'numpy',
#   're',
#   'warnings',
#   'pandas.tseries.holiday',
#   'statsmodels.formula.api'],
#  ['IPython.display', 'matplotlib.pyplot', 'scipy.optimize', 'numpy'],
#  ['pandas',
#   'numpy',
#   'matplotlib.pyplot',
#   'sklearn.neighbors',
#   'sklearn.tree',
#   'sklearn.grid_search',
#   'visuals',
#   'numpy',
#   'sklearn.metrics',
#   'sklearn.cross_validation'],
#  ['pandas',
#   'numpy',
#   'matplotlib.pyplot',
#   'sklearn.neighbors',
#   'sklearn.tree',
#   'sklearn.grid_search',
#   'visuals',
#   'numpy',
#   'sklearn.metrics',
#   'sklearn.cross_validation'],
#  ['threading',
#   'keras.preprocessing.image',
#   '__future__',
#   'os',
#   'numpy',
#   'keras.models',
#   'keras.layers',
#   're',
#   'scipy',
#   'keras.datasets',
#   'PIL',
#   'matplotlib',
#   'keras',
#   'keras.preprocessing.image',
#   'scipy.ndimage'],
#  ['pandas', 'os', 'matplotlib.pyplot', 'numpy'],
#  ['metrics.problems.zdt',
#   'nsga2.problems.zdt.zdt3_definitions',
#   'numpy',
#   'sys',
#   'matplotlib.pyplot',
#   'nsga2.problems.zdt',
#   'nsga2.evolution'],
#  ['pandas',
#   'pandas',
#   'sklearn.ensemble',
#   'matplotlib.pyplot',
#   'sklearn.tree',
#   'numpy',
#   'sklearn',
#   'sklearn.cross_validation'],
#  ['pandas', 'zipfile'],
#  ['pandas', 'zipfile'],
#  ['pandas',
#   'random',
#   'os',
#   'sklearn.utils',
#   'cv2',
#   'numpy',
#   'csv',
#   'keras.models',
#   'keras.layers',
#   'keras.optimizers',
#   'keras.callbacks',
#   'sklearn.model_selection'],
#  ['pandas',
#   'sklearn.ensemble',
#   'util_markdown',
#   'numpy',
#   'matplotlib.pyplot',
#   '__future__',
#   'seaborn',
#   'IPython.core.display',
#   'sklearn.neighbors',
#   'sklearn.grid_search',
#   'sklearn.metrics',
#   'time',
#   'sklearn.svm',
#   'math',
#   'sklearn.cross_validation'],
#  ['sklearn.datasets',
#   'sklearn.cluster',
#   'sklearn.metrics',
#   'numpy',
#   'matplotlib.pyplot'],
#  ['pandas',
#   'numpy',
#   'matplotlib.pyplot',
#   'sklearn.decomposition',
#   're',
#   'sklearn.discriminant_analysis',
#   'sklearn',
#   'gc'],
#  ['pandas',
#   'keras.utils.np_utils',
#   'keras.layers.recurrent',
#   'pyprind',
#   'numpy',
#   'keras.models',
#   'theano',
#   'warnings',
#   'IPython.display',
#   'keras.layers',
#   'keras.optimizers',
#   'keras'],
#  ['matplotlib.pyplot', 'graphlab', 'numpy', 'distutils.version'],
#  ['shared_content'],
#  ['matplotlib', 'numpy'],
#  ['random',
#   'pickle',
#   'scipy.misc',
#   'matplotlib.pyplot',
#   'sklearn.utils',
#   'tensorflow.contrib.layers',
#   'numpy',
#   'time',
#   'tensorflow'],
#  ['pandas', 'matplotlib.pyplot', 'numpy', 'math'],
#  ['pandas', 'matplotlib.pyplot', 'numpy', 'math'],
#  ['matplotlib.pyplot', 'seaborn'],
#  ['data.load', 'sys', 'numpy', 'gensim', 'sklearn.manifold', 'matplotlib'],
#  ['IPython.display'],
#  ['pandas', 'numpy', 'seaborn', 'pylab'],
#  ['pandas', 'os', 'json', 'numpy', 'cv2'],
#  ['pandas',
#   'sklearn.svm',
#   'sklearn.preprocessing',
#   'numpy',
#   'matplotlib.pyplot',
#   'pickle',
#   'sklearn.metrics',
#   'scipy',
#   'scipy.stats',
#   'sklearn',
#   'math',
#   'matplotlib',
#   'IPython.core.pylabtools'],
#  ['igraph'],
#  ['igraph'],
#  ['matplotlib.pyplot', 'random'],
#  ['os',
#   'scipy.optimize',
#   'sklearn',
#   'pandas',
#   'sklearn.ensemble',
#   'sklearn.pipeline',
#   'sklearn.linear_model',
#   'sklearn.svm',
#   'sklearn.feature_selection',
#   'multiprocessing',
#   'seaborn',
#   'sklearn.neural_network',
#   'numpy',
#   'sklearn.metrics',
#   'sklearn.model_selection',
#   'sklearn.cross_validation',
#   'sklearn.preprocessing',
#   'nibabel',
#   'matplotlib.pyplot',
#   'sklearn.decomposition'],
#  ['ConfigParser',
#   'collections',
#   'json',
#   'sys',
#   'matplotlib.pyplot',
#   'TwitterAPI',
#   'time',
#   'networkx',
#   'collections'],
#  ['pandas',
#   'matplotlib.pyplot',
#   'numpy',
#   'csv',
#   'sklearn.metrics',
#   'time',
#   'sklearn',
#   'math',
#   'sklearn.cross_validation'],
#  ['pandas',
#   'groupmeme',
#   'json',
#   'matplotlib.pyplot',
#   'groupmeme.group',
#   'sys',
#   'groupmeme.api'],
#  ['pandas',
#   'matplotlib.pyplot',
#   'seaborn',
#   'datetime',
#   'numpy',
#   'pymongo',
#   'scipy.stats.stats'],
#  ['pandas', 'getMag_hires', 'numpy', 'getMag', 'HELP', 'matplotlib'],
#  ['pandas',
#   'pivottablejs',
#   'IPython.display',
#   'matplotlib.pyplot',
#   'IPython.core.display',
#   'seaborn',
#   'numpy',
#   'statsmodels.formula.api'],
#  ['pandas',
#   'sklearn.metrics.regression',
#   'sklearn.preprocessing',
#   'numpy',
#   'matplotlib.pyplot',
#   'sklearn.tree',
#   'sklearn.model_selection',
#   'sklearn.linear_model',
#   'numpy',
#   'sklearn.svm'],
#  ['pandas',
#   'sklearn.metrics.regression',
#   'sklearn.preprocessing',
#   'numpy',
#   'matplotlib.pyplot',
#   'sklearn.tree',
#   'sklearn.model_selection',
#   'sklearn.linear_model',
#   'numpy',
#   'sklearn.svm'],
#  ['sunekutools'],
#  ['pandas', 'json'],
#  ['pandas',
#   'yelp.oauth1_authenticator',
#   'geojson',
#   'geopy.distance',
#   'random',
#   'bokeh.plotting',
#   'json',
#   'os',
#   'numpy',
#   'yelp.client',
#   'folium',
#   'requests',
#   'yelp.errors'],
#  ['cs231n.optim',
#   'matplotlib.pyplot',
#   'cs231n.data_utils',
#   'cs231n.gradient_check',
#   'numpy',
#   'cs231n.classifiers.fc_net',
#   'time',
#   'cs231n.solver',
#   'cs231n.layer_utils'],
#  ['pandas',
#   'sklearn.datasets',
#   'sklearn.datasets',
#   'matplotlib.pyplot',
#   'sklearn.cluster',
#   'numpy',
#   'sklearn.metrics',
#   'scipy.spatial.distance',
#   'scipy.cluster.hierarchy',
#   'matplotlib'],
#  ['pandas',
#   'sklearn.datasets',
#   'sklearn.datasets',
#   'matplotlib.pyplot',
#   'sklearn.cluster',
#   'numpy',
#   'sklearn.metrics',
#   'scipy.spatial.distance',
#   'scipy.cluster.hierarchy',
#   'matplotlib'],
#  ['pandas', 'numpy', 'statsmodels.api'],
#  ['pandas',
#   'numpy',
#   'matplotlib.pyplot',
#   'os',
#   'seaborn',
#   'datetime',
#   'pylab',
#   'sklearn.metrics',
#   'scipy',
#   'rasterio',
#   'glob',
#   'math',
#   'rasterio_to_xarray',
#   'xarray'],
#  ['pandas',
#   'image_proc',
#   'lbp',
#   'hog',
#   'random',
#   'svm',
#   'matplotlib.pyplot',
#   'kernels',
#   'os',
#   'numpy',
#   'sklearn.svm',
#   'im_transform'],
#  ['os',
#   'zipfile',
#   'matplotlib.image',
#   'os',
#   'matplotlib.pyplot',
#   'sklearn.utils',
#   'pickle',
#   'csv',
#   'numpy',
#   'cv2',
#   'scipy.ndimage.interpolation',
#   'tensorflow.contrib.layers',
#   'urllib.request',
#   'tensorflow'],
#  ['log'],
#  ['SimulationInstanceVectorized', 'SimulationMain', 'SimulationInstance'],
#  ['pandas',
#   'sklearn.preprocessing',
#   'sklearn.decomposition',
#   'seaborn',
#   'numpy',
#   'sklearn.model_selection',
#   'sklearn.manifold',
#   'matplotlib.pyplot'],
#  ['pandas',
#   'hmmlearn.hmm',
#   'asl_test_recognizer',
#   'numpy',
#   'unittest',
#   'timeit',
#   'my_recognizer',
#   'numpy',
#   'sklearn.model_selection',
#   'asl_data',
#   'warnings',
#   'math',
#   'matplotlib',
#   'asl_test_model_selectors',
#   'my_model_selectors',
#   'asl_utils'],
#  ['matplotlib.pylab', 'numpy', 'scipy'],
#  ['pandas', 'mne', 'numpy', 'matplotlib.pyplot', 'scipy', 'scipy.stats'],
#  ['pandas', 'matplotlib.pyplot', 'os', 'numpy'],
#  ['random', 'graphlab', 'numpy', 'math', 'matplotlib'],
#  ['base64',
#   'six.moves.urllib.request',
#   'os',
#   'matplotlib.pyplot',
#   '__future__',
#   'IPython.display',
#   'gzip',
#   'tensorflow'],
#  ['pandas',
#   'sklearn.ensemble',
#   'sklearn.preprocessing',
#   'json',
#   'matplotlib.pyplot',
#   'os',
#   'seaborn',
#   '__future__',
#   'sklearn.grid_search',
#   'numpy',
#   'sklearn.metrics',
#   'sklearn.linear_model',
#   'IPython.display',
#   'sklearn.svm',
#   'sklearn.naive_bayes',
#   'sklearn.cross_validation',
#   'matplotlib'],
#  ['obspy', 'numpy', 'matplotlib.pyplot', 'requests'],
#  ['time', 'matplotlib.pylab', 'numpy'],
#  ['time', 'matplotlib.pylab', 'numpy'],
#  ['matplotlib.pyplot',
#   'cs231n.data_utils',
#   'cs231n.gradient_check',
#   'numpy',
#   'cs231n.classifiers.fc_net',
#   'time',
#   'cs231n.solver'],
#  ['matplotlib.pyplot', 'sys', 'datetime', 'numpy', 'cv2', 'matplotlib'],
#  ['numpy', 'matplotlib.pyplot', 'os', 'sklearn', 'matplotlib', 'tensorflow'],
#  ['pandas', 'numpy.random', 'matplotlib.pyplot', 'seaborn', 'numpy'],
#  ['pytz',
#   'random',
#   'sklearn.utils',
#   'datetime',
#   'pandas',
#   'sklearn.feature_extraction.text',
#   'sklearn.ensemble',
#   'scipy.sparse',
#   'sklearn.linear_model',
#   're',
#   'copy',
#   'Levenshtein',
#   'numpy',
#   'sklearn.metrics',
#   'pymongo',
#   'sklearn.cross_validation',
#   'matplotlib.pyplot',
#   'nltk'],
#  ['pandas',
#   'numpy',
#   'matplotlib.pyplot',
#   'sklearn.model_selection',
#   'sklearn',
#   'sklearn.svm'],
#  ['pandas'],
#  ['pandas',
#   'urllib2',
#   'json',
#   'matplotlib.pyplot',
#   'sklearn.grid_search',
#   'bs4',
#   'statsmodels.api',
#   'numpy',
#   'sklearn.metrics',
#   're',
#   'sklearn.linear_model',
#   'sklearn.cross_validation',
#   'requests'],
#  ['mpl_toolkits.axes_grid1',
#   'sympy',
#   'sympy.interactive',
#   'numpy',
#   'matplotlib.pyplot',
#   'scipy.stats'],
#  ['skimage.color',
#   'skimage.filters',
#   'numpy',
#   'skimage.measure',
#   'matplotlib.pyplot',
#   'skimage.morphology',
#   'skimage.segmentation',
#   'skimage'],
#  ['pandas',
#   'math',
#   'sklearn.preprocessing',
#   'matplotlib.pyplot',
#   'scipy.optimize',
#   'sklearn.pipeline',
#   'numpy',
#   'sklearn.linear_model',
#   'sklearn'],
#  ['pandas',
#   'collections',
#   'os',
#   'matplotlib.pyplot',
#   'pickle',
#   'gensim.models.word2vec',
#   'sklearn.linear_model',
#   'numpy',
#   'operator',
#   'scipy',
#   'sklearn',
#   'matplotlib'],
#  ['pandas',
#   'random',
#   'matplotlib.pyplot',
#   'datetime',
#   'numpy',
#   'time',
#   'MySQLdb'],
#  ['pandas',
#   'random',
#   'matplotlib.pyplot',
#   'datetime',
#   'numpy',
#   'time',
#   'MySQLdb'],
#  ['astropy.table',
#   'pandas',
#   'astropy',
#   'astropy.modeling',
#   'os',
#   'numpy',
#   're',
#   'astropy.io',
#   'matplotlib.pyplot'],
#  ['pandas',
#   'nltk.corpus',
#   'collections',
#   'nltk',
#   'scipy.fftpack',
#   'matplotlib.pyplot',
#   'nltk',
#   'numpy',
#   'matplotlib'],
#  ['pandas', 're', 'pandas'],
#  ['copy',
#   'pdb',
#   'numpy',
#   'matplotlib.pyplot',
#   'sklearn.linear_model',
#   'lassoData',
#   'math'],
#  ['pandas',
#   'hmmlearn.hmm',
#   'asl_test_recognizer',
#   'numpy',
#   'unittest',
#   'timeit',
#   'my_recognizer',
#   'sklearn.model_selection',
#   'asl_data',
#   'warnings',
#   'math',
#   'matplotlib',
#   'asl_test_model_selectors',
#   'my_model_selectors',
#   'asl_utils'],
#  ['pandas',
#   'random',
#   'netCDF4',
#   'matplotlib.pyplot',
#   'statsmodels.api',
#   'numpy',
#   'netCDF4',
#   'pymc3',
#   'scipy',
#   'glob',
#   'pandas.stats.api'],
#  ['random',
#   'pyspark.mllib.regression',
#   'pyspark.sql',
#   'json',
#   'matplotlib.pyplot',
#   'pylab',
#   'scipy.sparse',
#   'numpy',
#   'operator',
#   'time',
#   'string',
#   'pyspark.mllib.classification'],
#  ['matplotlib.pylab',
#   'numpy',
#   'mpl_toolkits.basemap',
#   'datetime',
#   'numpy',
#   'netCDF4'],
#  ['pandas'],
#  ['pandas', 'scipy.cluster.hierarchy', 'scipy.spatial.distance'],
#  ['random',
#   'urllib.request',
#   'sklearn.preprocessing',
#   'matplotlib.pyplot',
#   'problem_unittests',
#   'pickle',
#   'numpy',
#   'tqdm',
#   'sklearn',
#   'tarfile',
#   'tensorflow',
#   'os.path'],
#  ['numpy', 'flopy', 'os'],
#  ['pandas',
#   'sklearn.cluster',
#   'sklearn.metrics',
#   'numpy',
#   'sklearn',
#   'matplotlib.pyplot'],
#  ['base64',
#   'six.moves.urllib.request',
#   'pkg_resources',
#   'os',
#   'matplotlib.pyplot',
#   '__future__',
#   'IPython.display',
#   'gzip',
#   'tensorflow'],
#  ['pandas',
#   'os',
#   'matplotlib.pyplot',
#   'sys',
#   'seaborn',
#   'numpy',
#   'scipy.stats',
#   'maskfunctions',
#   'statsmodels'],
#  ['pandas', 'scipy.cluster.hierarchy', 'scipy.spatial.distance'],
#  ['LsqFit', 'Scical', 'PyPlot'],
#  ['pandas', 'zipfile'],
#  ['pandas', 'zipfile'],
#  ['mpl_toolkits.mplot3d', 'matplotlib', 'numpy', 'matplotlib'],
#  ['base64',
#   'six.moves.urllib.request',
#   'os',
#   'matplotlib.pyplot',
#   '__future__',
#   'IPython.display',
#   'gzip',
#   'tensorflow'],
#  ['base64',
#   'six.moves.urllib.request',
#   'os',
#   'matplotlib.pyplot',
#   '__future__',
#   'IPython.display',
#   'gzip',
#   'tensorflow'],
#  ['pandas', 'cmath', 'numpy', 'scipy'],
#  ['pandas',
#   'hmmlearn.hmm',
#   'asl_test_recognizer',
#   'numpy',
#   'unittest',
#   'timeit',
#   'my_recognizer',
#   'sklearn.model_selection',
#   'asl_data',
#   'warnings',
#   'math',
#   'matplotlib',
#   'asl_test_model_selectors',
#   'my_model_selectors',
#   'asl_utils'],
#  ['numpy',
#   'matplotlib.pyplot',
#   'os',
#   'seaborn',
#   'timeit',
#   'theano.tensor',
#   'theano'],
#  ['pandas',
#   'sklearn.base',
#   'os',
#   'sklearn.decomposition',
#   'seaborn',
#   'numpy',
#   'sklearn',
#   'xgboost'],
#  ['pandas',
#   'codecs',
#   'sklearn.feature_extraction.text',
#   'nltk.corpus',
#   'sklearn.externals',
#   'numpy',
#   'os',
#   '__future__',
#   'sklearn.cluster',
#   'nltk',
#   'mpld3',
#   're',
#   'sklearn.metrics.pairwise',
#   'sklearn',
#   'string',
#   'nltk.stem.snowball'],
#  ['pandas',
#   'requests',
#   'matplotlib.pyplot',
#   'bs4',
#   'dateutil.parser',
#   'numpy',
#   'time',
#   're',
#   'matplotlib'],
#  ['copy',
#   'matplotlib.pyplot',
#   'numpy',
#   'networkx',
#   'sklearn.svm',
#   'collections'],
#  ['iuvs'],
#  ['pandas', 'pandas_datareader', 'matplotlib.pyplot', 'numpy'],
#  ['pandas',
#   'sklearn.ensemble',
#   'pandas.tools.plotting',
#   'csv',
#   'sklearn.preprocessing',
#   'matplotlib.pyplot',
#   'sklearn.decomposition',
#   'sklearn.cluster',
#   'numpy',
#   'sklearn.metrics',
#   'sklearn'],
#  ['base64',
#   'six.moves.urllib.request',
#   'os',
#   'matplotlib.pyplot',
#   '__future__',
#   'IPython.display',
#   'gzip',
#   'tensorflow'],
#  ['base64',
#   'six.moves.urllib.request',
#   'os',
#   'matplotlib.pyplot',
#   '__future__',
#   'IPython.display',
#   'gzip',
#   'tensorflow'],
#  ['pandas'],
#  ['pandas', 'seaborn', 'numpy', 'astropy.cosmology', 'matplotlib.pyplot'],
#  ['lattice', 'system', 'math', 'plot'],
#  ['pandas', 'numpy', 'scipy.stats', 'math'],
#  ['base64',
#   'six.moves.urllib.request',
#   'os',
#   'matplotlib.pyplot',
#   '__future__',
#   'IPython.display',
#   'gzip',
#   'tensorflow'],
#  ['mpl_toolkits.mplot3d', 'pygadgetreader', 'matplotlib'],
#  ['base64',
#   'six.moves.urllib.request',
#   'os',
#   'matplotlib.pyplot',
#   '__future__',
#   'IPython.display',
#   'gzip',
#   'tensorflow'],
#  ['pandas',
#   'pydotplus',
#   'matplotlib.pyplot',
#   'sklearn.tree',
#   'numpy',
#   'sklearn.model_selection',
#   'sklearn.externals.six',
#   'itertools',
#   'sklearn',
#   'IPython.display',
#   'sklearn.metrics'],
#  ['pandas',
#   'random',
#   'sklearn.datasets',
#   'sklearn.preprocessing',
#   'matplotlib.pyplot',
#   'statsmodels.api',
#   'sklearn.metrics',
#   'sklearn.linear_model',
#   'numpy',
#   'sklearn.cross_validation',
#   'statsmodels.formula.api',
#   'matplotlib.pyplot'],
#  ['math',
#   'caffe',
#   'matplotlib.pyplot',
#   'sys',
#   'os',
#   'pickle',
#   'numpy',
#   'scipy.cluster.vq',
#   'time'],
#  ['pandas',
#   'pandas',
#   'bokeh.models',
#   'matplotlib.pyplot',
#   'bokeh.io',
#   'seaborn',
#   'datetime',
#   'numpy'],
#  ['astropy.table', 'mica.stats.acq_stats', 'matplotlib.pyplot'],
#  ['threading',
#   'keras.preprocessing.image',
#   '__future__',
#   'os',
#   'numpy',
#   'keras.models',
#   'keras.layers',
#   're',
#   'scipy',
#   'keras.datasets',
#   'PIL',
#   'matplotlib',
#   'keras',
#   'keras.preprocessing.image',
#   'scipy.ndimage'],
#  ...]

# %% [markdown]
# ## Saving list to text file

# %%
import pickle
with open("../data/Txt_files/apriori.txt", "wb") as fp:   #Pickling
    pickle.dump(result, fp)
with open("../data/Txt_files/apriori.txt", "rb") as fp:   # Unpickling
    Imports_apr = pickle.load(fp)
